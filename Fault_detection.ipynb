# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('Training_data.csv')

# %%
data.head()
# Out:
#    systemLoad  gridTHD_a  gridTHD_b  gridTHD_c driverFault
# 0           8   0.113788   0.114715   0.115290         '0'
# 1           8   0.328191   0.280657   0.335213         '1'
# 2           8   0.329854   0.282814   0.335284         '1'
# 3           8   0.415659   0.334507   0.557096         '1'
# 4           8   0.281618   0.335353   0.330582        '10'

# %%
Feature = ['systemLoad' ,	'gridTHD_a' ,	'gridTHD_b' ,	'gridTHD_c']

# %%
X_train = data[Feature]
X_train.head()
# Out:
#    systemLoad  gridTHD_a  gridTHD_b  gridTHD_c
# 0           8   0.113788   0.114715   0.115290
# 1           8   0.328191   0.280657   0.335213
# 2           8   0.329854   0.282814   0.335284
# 3           8   0.415659   0.334507   0.557096
# 4           8   0.281618   0.335353   0.330582

# %%
y = data.driverFault
y.head()
# Out:
# 0     '0'
# 1     '1'
# 2     '1'
# 3     '1'
# 4    '10'
# Name: driverFault, dtype: object

# %%
import pandas as pd
y = data['driverFault'].str.strip("'")

# Convert the cleaned column to a list of floats
y_train = [int(item) for item in y]

# Print the list of float
print(y_train);
# Out:
# [0, 1, 1, 1, 10, 11, 11, 11, 10, 11, 11, 11, 10, 11, 11, 11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 0, 1, 1, 1, 10, 11, 11, 11, 10, 11, 11, 11, 10, 11, 11, 11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 0, 1, 1, 1, 10, 11, 11, 11, 10, 11, 11, 11, 10, 11, 11, 11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 0, 1, 1, 1, 10, 11, 11, 11, 10, 11, 11, 11, 10, 11, 11, 11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 0, 1, 1, 1, 10, 11, 11, 11, 10, 11, 11, 11, 10, 11, 11, 11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110]

# %%
df = pd.read_csv('Test_Data.csv')

# %%
df.head()
# Out:
#    systemLoad  gridTHD_a  gridTHD_b  gridTHD_c driverFault
# 0         9.5   0.141286   0.141963   0.143521         '0'
# 1         9.5   0.336371   0.307908   0.376937         '1'
# 2         9.5   0.343918   0.305359   0.377182         '1'
# 3         9.5   0.406348   0.329591   0.563125         '1'
# 4         9.5   0.310914   0.381471   0.345124        '10'

# %%
X_test = df[Feature]
X_test.head()
# Out:
#    systemLoad  gridTHD_a  gridTHD_b  gridTHD_c
# 0         9.5   0.141286   0.141963   0.143521
# 1         9.5   0.336371   0.307908   0.376937
# 2         9.5   0.343918   0.305359   0.377182
# 3         9.5   0.406348   0.329591   0.563125
# 4         9.5   0.310914   0.381471   0.345124

# %%
y1 = df.driverFault
y1.head()
# Out:
# 0     '0'
# 1     '1'
# 2     '1'
# 3     '1'
# 4    '10'
# Name: driverFault, dtype: object

# %%
import pandas as pd
y1 = df['driverFault'].str.strip("'")

# Convert the cleaned column to a list of floats
y_test = [int(item) for item in y]

# Print the list of float
y_test
# Out:
# [0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error, make_scorer
import numpy as np

model = tree.DecisionTreeClassifier(random_state=42)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([  0,   1,   1,   1,  10,  11, 100, 110,  10, 100,  11, 110,  10,
#         11,  11,  11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101,
#        101, 110, 110, 110, 100,  11,  11, 101, 110, 110, 110,   0,   1,
#          1,   1,  10,  11,  11,  11,  10,  11,  11,  11, 101,  11,  11,
#         11, 100, 101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110,
#        110, 110, 100, 101, 101, 101, 110, 110, 110,   0,   1,   1,   1,
#         10,  11,  11,  11,  10,  11,  11,  11,  10,  11,  11,  11, 100,
#        101, 101, 101, 110, 110, 110, 100, 101, 101, 101, 110, 110, 110,
#        100, 101, 101, 101, 110, 110, 110])

# %%
y_pred = [int(item) for item in y]

# Print the list of float
y_pred
# Out:
# [0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  0,
#  1,
#  1,
#  1,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  100,
#  101,
#  101,
#  101,
#  110,
#  110,
#  110,
#  100,
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues', values_format='d')
